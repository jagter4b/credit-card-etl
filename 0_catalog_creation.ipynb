# %%
# %sql
drop catalog prod cascade;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS prod; 
CREATE SCHEMA IF NOT EXISTS prod.bronze_raw
COMMENT 'raw ingestion layer for transations';

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS prod.silver 
COMMENT 'cleaned layer for transations pipeline'

# %%
# %sql 
CREATE SCHEMA IF NOT EXISTS prod.gold 
COMMENT 'star-schema layer'
